# %%
# To zhuzhu

import re
import requests
import pandas as pd
import numpy as np
from time import sleep
import bs4
from bs4 import BeautifulSoup
import pickle # for loading a dictionary from disk
from typing import Optional # typehint that value can also be None
from dataprep.clean import validate_country
from dataprep.clean import clean_country
# Out:
# Note: NumExpr detected 10 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# NumExpr defaulting to 8 threads.

# %%
#!pip install dataprep

# %%
import spacy
from spacy import displacy
import warnings
warnings.filterwarnings("ignore")

# Larger and slower pipeline but more accurate
# spacy.cli.download("en_core_web_trf")
# NER= spacy.load("en_core_web_trf")
                   
# Faster and smaller pipelien, less accurate                   
spacy.cli.download("en_core_web_sm")
NER= spacy.load("en_core_web_sm")

def extract_country_from_abstract(abs_string):
    text_ner = NER(abs_string)
    #displacy.render(text_ner,style="ent",jupyter=True)

    # Extract the text from each tag
    tag_list = np.array([X.text for X in text_ner.ents])
 #   tag_list_df = pd.DataFrame({ "country": tag_list })
  #  tag_list_clean = clean_country(tag_list_df, "country").country_clean.values
    GPE_mask = np.array([X.label_ =='GPE'  for X in text_ner.ents])
    LOC_mask= np.array([X.label_ =='LOC'  for X in text_ner.ents])
    mask = [validate_country(tag) for tag in tag_list]

    # Abstract_valid_country
    abs_country = tag_list[mask]
    #abs_GPE 
    GPE_list,LOC_list = [],[]
    if len(GPE_mask)>0:
      GPE_list = tag_list[GPE_mask]
    if len(LOC_mask)>0:
      LOC_list = tag_list[LOC_mask]
    return abs_country, GPE_list, LOC_list
# Out:
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')

# %%
def read_journal(url_list):
    res = pd.DataFrame(columns= ['DOI','Journal','Type','Title','Publish_Time','Issue_Time','Co_Author','Author','Rank','Nationality','Abs_country','Abs_GPE','Abs_LOC'])
    i=0
    for url in url_list:
        home_page = requests.get(url)
        raw_html = home_page.text
        soup = BeautifulSoup(raw_html, 'html.parser')
        
        journal = soup.find('div',{'class':"row crumbs-row"}).find_all('li',{'class':"page-breadcrumbs__item"})[2].find_all('span')[-1].get_text()
        # create a new row for each author
        main_content = soup.find('div',{'id':"maincontent"})
        title = main_content.find('h1').get_text()
        contributors_details = main_content.find_all('div',{'class':'row author'})
        published_date = main_content.find('div',{'class':"row published-date"}).find('strong').get_text()
        # Extract country information from abstract
        abs_tag = soup.find('div',{'class':'abstract-text-container'})
        if type(abs_tag)== bs4.element.Tag:
          abs_text = abs_tag.find('div',{'lang':'en'}).find('p').get_text()
          abs_country, GPE_list, LOC_list = extract_country_from_abstract(abs_text)
        else:
          abs_country, GPE_list, LOC_list = [],[],[]

        
        article_details = soup.find('dl',{'class':"article-details"})
        Type = article_details.find('div',{'class':'row'}).find('dd').get_text()
        issue_time = article_details.find('div',{'class':'content__journal'}).find_all('span')[-2].get_text().strip(',')

        doi = article_details.find('div',{'class':"doi-data"}).find('span').get_text()

        for author_describe_idx in range(len(contributors_details)):
            author_describe = contributors_details[author_describe_idx]
            temp_dict={}
            temp_dict['Co_Author'] = len(contributors_details) > 1
            temp_dict['Author']=author_describe.get('data-test-author')
            temp_dict['Rank'] = 'First' if (author_describe_idx == 0) else 'Communication' \
                                if (author_describe_idx == len(contributors_details)-1) else 'Other'
            temp_dict['Nationality'] = author_describe.find_all('span')[-1].get_text().split(',')[-1].strip()
            temp_dict['Publish_Time']= published_date
            temp_dict['Issue_Time']= issue_time
            temp_dict['Title']= title
            temp_dict['Journal']= journal
            temp_dict['DOI']= doi
            temp_dict['Type']= Type
            temp_dict['Abs_country'] = abs_country
            temp_dict['Abs_GPE'] = GPE_list
            temp_dict['Abs_LOC'] = LOC_list
            res = res.append(temp_dict, ignore_index=True)
        i+=1
        print(f'Processing the {i}th paper with {len(contributors_details)} authors')
    return res

# %%
url = 'https://www.cambridge.org/core/journals/american-antiquity/all-issues'
base_url = 'https://www.cambridge.org'

# %%
def Antiquity_issues_url(url,base_url): 
    issues_list= [] 
    home_page = requests.get(url)
    raw_html = home_page.text
    soup = BeautifulSoup(raw_html, 'html.parser')
    all_issues = soup.find('div',{'class':'reading-width journal-all-issues'})
    Time_range = ['decade2020','decade2010','decade2000']
    for dec in Time_range:
        panels = all_issues.find('div',{'id':dec}).find('ul',{'class':'accordion level second'}).find_all('li',recursive=False)
        for volume in panels:
            issues = volume.find('div',recursive=False).find_all('a')
            for issue in issues:
                issue_url = base_url + issue.get('href')
                issues_list.append(issue_url)
    return issues_list

# %%
issues_url = Antiquity_issues_url(url,base_url)

# %%
def Antiquity_papers_url(issues_url):
    url_list=[]
    i=0
    for url in issues_url:
        home_page = requests.get(url)
        raw_html = home_page.text
        soup = BeautifulSoup(raw_html, 'html.parser').find('div',{'class':'panel large-9 small-12 column main-column','id':'maincontent'})
        soup = soup.find('div',{'class':'results'}).find('div',{'class':'large-12 columns margin-top'})
        
        target = soup.find('h4',text ='Reports' )
        if target != None:
            for e in target.find_all_next():
                e.clear()
                
        target = soup.find('h4',text ='Report' )
        if target != None:
            for e in target.find_all_next():
                e.clear()
        '''
        
        
        elif soup.find('h4',text ='Front Cover (OFC, IFC) and matter' ) != None:
            target = soup.find('h4',text ='Front Cover (OFC, IFC) and matter' )
            for e in target.find_all_next():
                e.clear()
                
        elif soup.find('h4',text ='Back Cover (IBC, OBC) and matter' ) != None:
            target = soup.find('h4',text ='Back Cover (IBC, OBC) and matter' )
            for e in target.find_all_next():
                e.clear() 
        '''
                
        res = soup.find_all('div',{'class':'representation overview search'})
        for paper in res:
            try:
                add_url = paper.find('li',{'class':'title'}).find('a').get('href')
                url_list.append(base_url+add_url)
                i+=1
                print(f'Appeding the {i}th url')
            except:
                pass
    return url_list

# %%
url_list = Antiquity_papers_url(issues_url)
# Out:
# Appeding the 1th url
# Appeding the 2th url
# Appeding the 3th url
# Appeding the 4th url
# Appeding the 5th url
# Appeding the 6th url
# Appeding the 7th url
# Appeding the 8th url
# Appeding the 9th url
# Appeding the 10th url
# Appeding the 11th url
# Appeding the 12th url
# Appeding the 13th url
# Appeding the 14th url
# Appeding the 15th url
# Appeding the 16th url
# Appeding the 17th url
# Appeding the 18th url
# Appeding the 19th url
# Appeding the 20th url
# Appeding the 21th url
# Appeding the 22th url
# Appeding the 23th url
# Appeding the 24th url
# Appeding the 25th url
# Appeding the 26th url
# Appeding the 27th url
# Appeding the 28th url
# Appeding the 29th url
# Appeding the 30th url
# Appeding the 31th url
# Appeding the 32th url
# Appeding the 33th url
# Appeding the 34th url
# Appeding the 35th url
# Appeding the 36th url
# Appeding the 37th url
# Appeding the 38th url
# Appeding the 39th url
# Appeding the 40th url
# Appeding the 41th url
# Appeding the 42th url
# Appeding the 43th url
# Appeding the 44th url
# Appeding the 45th url
# Appeding the 46th url
# Appeding the 47th url
# Appeding the 48th url
# Appeding the 49th url
# Appeding the 50th url
# Appeding the 51th url
# Appeding the 52th url
# Appeding the 53th url
# Appeding the 54th url
# Appeding the 55th url
# Appeding the 56th url
# Appeding the 57th url
# Appeding the 58th url
# Appeding the 59th url
# Appeding the 60th url
# Appeding the 61th url
# Appeding the 62th url
# Appeding the 63th url
# Appeding the 64th url
# Appeding the 65th url
# Appeding the 66th url
# Appeding the 67th url
# Appeding the 68th url
# Appeding the 69th url
# Appeding the 70th url
# Appeding the 71th url
# Appeding the 72th url
# Appeding the 73th url
# Appeding the 74th url
# Appeding the 75th url
# Appeding the 76th url
# Appeding the 77th url
# Appeding the 78th url
# Appeding the 79th url
# Appeding the 80th url
# Appeding the 81th url
# Appeding the 82th url
# Appeding the 83th url
# Appeding the 84th url
# Appeding the 85th url
# Appeding the 86th url
# Appeding the 87th url
# Appeding the 88th url
# Appeding the 89th url
# Appeding the 90th url
# Appeding the 91th url
# Appeding the 92th url
# Appeding the 93th url
# Appeding the 94th url
# Appeding the 95th url
# Appeding the 96th url
# Appeding the 97th url
# Appeding the 98th url
# Appeding the 99th url
# Appeding the 100th url
# Appeding the 101th url
# Appeding the 102th url
# Appeding the 103th url
# Appeding the 104th url
# Appeding the 105th url
# Appeding the 106th url
# Appeding the 107th url
# Appeding the 108th url
# Appeding the 109th url
# Appeding the 110th url
# Appeding the 111th url
# Appeding the 112th url
# Appeding the 113th url
# Appeding the 114th url
# Appeding the 115th url
# Appeding the 116th url
# Appeding the 117th url
# Appeding the 118th url
# Appeding the 119th url
# Appeding the 120th url
# Appeding the 121th url
# Appeding the 122th url
# Appeding the 123th url
# Appeding the 124th url
# Appeding the 125th url
# Appeding the 126th url
# Appeding the 127th url
# Appeding the 128th url
# Appeding the 129th url
# Appeding the 130th url
# Appeding the 131th url
# Appeding the 132th url
# Appeding the 133th url
# Appeding the 134th url
# Appeding the 135th url
# Appeding the 136th url
# Appeding the 137th url
# Appeding the 138th url
# Appeding the 139th url
# Appeding the 140th url
# Appeding the 141th url
# Appeding the 142th url
# Appeding the 143th url
# Appeding the 144th url
# Appeding the 145th url
# Appeding the 146th url
# Appeding the 147th url
# Appeding the 148th url
# Appeding the 149th url
# Appeding the 150th url
# Appeding the 151th url
# Appeding the 152th url
# Appeding the 153th url
# Appeding the 154th url
# Appeding the 155th url
# Appeding the 156th url
# Appeding the 157th url
# Appeding the 158th url
# Appeding the 159th url
# Appeding the 160th url
# Appeding the 161th url
# Appeding the 162th url
# Appeding the 163th url
# Appeding the 164th url
# Appeding the 165th url
# Appeding the 166th url
# Appeding the 167th url
# Appeding the 168th url
# Appeding the 169th url
# Appeding the 170th url
# Appeding the 171th url
# Appeding the 172th url
# Appeding the 173th url
# Appeding the 174th url
# Appeding the 175th url
# Appeding the 176th url
# Appeding the 177th url
# Appeding the 178th url
# Appeding the 179th url
# Appeding the 180th url
# Appeding the 181th url
# Appeding the 182th url
# Appeding the 183th url
# Appeding the 184th url
# Appeding the 185th url
# Appeding the 186th url
# Appeding the 187th url
# Appeding the 188th url
# Appeding the 189th url
# Appeding the 190th url
# Appeding the 191th url
# Appeding the 192th url
# Appeding the 193th url
# Appeding the 194th url
# Appeding the 195th url
# Appeding the 196th url
# Appeding the 197th url
# Appeding the 198th url
# Appeding the 199th url
# Appeding the 200th url
# Appeding the 201th url
# Appeding the 202th url
# Appeding the 203th url
# Appeding the 204th url
# Appeding the 205th url
# Appeding the 206th url
# Appeding the 207th url
# Appeding the 208th url
# Appeding the 209th url
# Appeding the 210th url
# Appeding the 211th url
# Appeding the 212th url
# Appeding the 213th url
# Appeding the 214th url
# Appeding the 215th url
# Appeding the 216th url
# Appeding the 217th url
# Appeding the 218th url
# Appeding the 219th url
# Appeding the 220th url
# Appeding the 221th url
# Appeding the 222th url
# Appeding the 223th url
# Appeding the 224th url
# Appeding the 225th url
# Appeding the 226th url
# Appeding the 227th url
# Appeding the 228th url
# Appeding the 229th url
# Appeding the 230th url
# Appeding the 231th url
# Appeding the 232th url
# Appeding the 233th url
# Appeding the 234th url
# Appeding the 235th url
# Appeding the 236th url
# Appeding the 237th url
# Appeding the 238th url
# Appeding the 239th url
# Appeding the 240th url
# Appeding the 241th url
# Appeding the 242th url
# Appeding the 243th url
# Appeding the 244th url
# Appeding the 245th url
# Appeding the 246th url
# Appeding the 247th url
# Appeding the 248th url
# Appeding the 249th url
# Appeding the 250th url
# Appeding the 251th url
# Appeding the 252th url
# Appeding the 253th url
# Appeding the 254th url
# Appeding the 255th url
# Appeding the 256th url
# Appeding the 257th url
# Appeding the 258th url
# Appeding the 259th url
# Appeding the 260th url
# Appeding the 261th url
# Appeding the 262th url
# Appeding the 263th url
# Appeding the 264th url
# Appeding the 265th url
# Appeding the 266th url
# Appeding the 267th url
# Appeding the 268th url
# Appeding the 269th url
# Appeding the 270th url
# Appeding the 271th url
# Appeding the 272th url
# Appeding the 273th url
# Appeding the 274th url
# Appeding the 275th url
# Appeding the 276th url
# Appeding the 277th url
# Appeding the 278th url
# Appeding the 279th url
# Appeding the 280th url
# Appeding the 281th url
# Appeding the 282th url
# Appeding the 283th url
# Appeding the 284th url
# Appeding the 285th url
# Appeding the 286th url
# Appeding the 287th url
# Appeding the 288th url
# Appeding the 289th url
# Appeding the 290th url
# Appeding the 291th url
# Appeding the 292th url
# Appeding the 293th url
# Appeding the 294th url
# Appeding the 295th url
# Appeding the 296th url
# Appeding the 297th url
# Appeding the 298th url
# Appeding the 299th url
# Appeding the 300th url
# Appeding the 301th url
# Appeding the 302th url
# Appeding the 303th url
# Appeding the 304th url
# Appeding the 305th url
# Appeding the 306th url
# Appeding the 307th url
# Appeding the 308th url
# Appeding the 309th url
# Appeding the 310th url
# Appeding the 311th url
# Appeding the 312th url
# Appeding the 313th url
# Appeding the 314th url
# Appeding the 315th url
# Appeding the 316th url
# Appeding the 317th url
# Appeding the 318th url
# Appeding the 319th url
# Appeding the 320th url
# Appeding the 321th url
# Appeding the 322th url
# Appeding the 323th url
# Appeding the 324th url
# Appeding the 325th url
# Appeding the 326th url
# Appeding the 327th url
# Appeding the 328th url
# Appeding the 329th url
# Appeding the 330th url
# Appeding the 331th url
# Appeding the 332th url
# Appeding the 333th url
# Appeding the 334th url
# Appeding the 335th url
# Appeding the 336th url
# Appeding the 337th url
# Appeding the 338th url
# Appeding the 339th url
# Appeding the 340th url
# Appeding the 341th url
# Appeding the 342th url
# Appeding the 343th url
# Appeding the 344th url
# Appeding the 345th url
# Appeding the 346th url
# Appeding the 347th url
# Appeding the 348th url
# Appeding the 349th url
# Appeding the 350th url
# Appeding the 351th url
# Appeding the 352th url
# Appeding the 353th url
# Appeding the 354th url
# Appeding the 355th url
# Appeding the 356th url
# Appeding the 357th url
# Appeding the 358th url
# Appeding the 359th url
# Appeding the 360th url
# Appeding the 361th url
# Appeding the 362th url
# Appeding the 363th url
# Appeding the 364th url
# Appeding the 365th url
# Appeding the 366th url
# Appeding the 367th url
# Appeding the 368th url
# Appeding the 369th url
# Appeding the 370th url
# Appeding the 371th url
# Appeding the 372th url
# Appeding the 373th url
# Appeding the 374th url
# Appeding the 375th url
# Appeding the 376th url
# Appeding the 377th url
# Appeding the 378th url
# Appeding the 379th url
# Appeding the 380th url
# Appeding the 381th url
# Appeding the 382th url
# Appeding the 383th url
# Appeding the 384th url
# Appeding the 385th url
# Appeding the 386th url
# Appeding the 387th url
# Appeding the 388th url
# Appeding the 389th url
# Appeding the 390th url
# Appeding the 391th url
# Appeding the 392th url
# Appeding the 393th url
# Appeding the 394th url
# Appeding the 395th url
# Appeding the 396th url
# Appeding the 397th url
# Appeding the 398th url
# Appeding the 399th url
# Appeding the 400th url
# Appeding the 401th url
# Appeding the 402th url
# Appeding the 403th url
# Appeding the 404th url
# Appeding the 405th url
# Appeding the 406th url
# Appeding the 407th url
# Appeding the 408th url
# Appeding the 409th url
# Appeding the 410th url
# Appeding the 411th url
# Appeding the 412th url
# Appeding the 413th url
# Appeding the 414th url
# Appeding the 415th url
# Appeding the 416th url
# Appeding the 417th url
# Appeding the 418th url
# Appeding the 419th url
# Appeding the 420th url
# Appeding the 421th url
# Appeding the 422th url
# Appeding the 423th url
# Appeding the 424th url
# Appeding the 425th url
# Appeding the 426th url
# Appeding the 427th url
# Appeding the 428th url
# Appeding the 429th url
# Appeding the 430th url
# Appeding the 431th url
# Appeding the 432th url
# Appeding the 433th url
# Appeding the 434th url
# Appeding the 435th url
# Appeding the 436th url
# Appeding the 437th url
# Appeding the 438th url
# Appeding the 439th url
# Appeding the 440th url
# Appeding the 441th url
# Appeding the 442th url
# Appeding the 443th url
# Appeding the 444th url
# Appeding the 445th url
# Appeding the 446th url
# Appeding the 447th url
# Appeding the 448th url
# Appeding the 449th url
# Appeding the 450th url
# Appeding the 451th url
# Appeding the 452th url
# Appeding the 453th url
# Appeding the 454th url
# Appeding the 455th url
# Appeding the 456th url
# Appeding the 457th url
# Appeding the 458th url
# Appeding the 459th url
# Appeding the 460th url
# Appeding the 461th url
# Appeding the 462th url
# Appeding the 463th url
# Appeding the 464th url
# Appeding the 465th url
# Appeding the 466th url
# Appeding the 467th url
# Appeding the 468th url
# Appeding the 469th url
# Appeding the 470th url
# Appeding the 471th url
# Appeding the 472th url
# Appeding the 473th url
# Appeding the 474th url
# Appeding the 475th url
# Appeding the 476th url
# Appeding the 477th url
# Appeding the 478th url
# Appeding the 479th url
# Appeding the 480th url
# Appeding the 481th url
# Appeding the 482th url
# Appeding the 483th url
# Appeding the 484th url
# Appeding the 485th url
# Appeding the 486th url
# Appeding the 487th url
# Appeding the 488th url
# Appeding the 489th url
# Appeding the 490th url
# Appeding the 491th url
# Appeding the 492th url
# Appeding the 493th url
# Appeding the 494th url
# Appeding the 495th url
# Appeding the 496th url
# Appeding the 497th url
# Appeding the 498th url
# Appeding the 499th url
# Appeding the 500th url
# Appeding the 501th url
# Appeding the 502th url
# Appeding the 503th url
# Appeding the 504th url
# Appeding the 505th url
# Appeding the 506th url
# Appeding the 507th url
# Appeding the 508th url
# Appeding the 509th url
# Appeding the 510th url
# Appeding the 511th url
# Appeding the 512th url
# Appeding the 513th url
# Appeding the 514th url
# Appeding the 515th url
# Appeding the 516th url
# Appeding the 517th url
# Appeding the 518th url
# Appeding the 519th url
# Appeding the 520th url
# Appeding the 521th url
# Appeding the 522th url
# Appeding the 523th url
# Appeding the 524th url
# Appeding the 525th url
# Appeding the 526th url
# Appeding the 527th url
# Appeding the 528th url
# Appeding the 529th url
# Appeding the 530th url
# Appeding the 531th url
# Appeding the 532th url
# Appeding the 533th url
# Appeding the 534th url
# Appeding the 535th url
# Appeding the 536th url
# Appeding the 537th url
# Appeding the 538th url
# Appeding the 539th url
# Appeding the 540th url
# Appeding the 541th url
# Appeding the 542th url
# Appeding the 543th url
# Appeding the 544th url
# Appeding the 545th url
# Appeding the 546th url
# Appeding the 547th url
# Appeding the 548th url
# Appeding the 549th url
# Appeding the 550th url
# Appeding the 551th url
# Appeding the 552th url
# Appeding the 553th url
# Appeding the 554th url
# Appeding the 555th url
# Appeding the 556th url
# Appeding the 557th url
# Appeding the 558th url
# Appeding the 559th url
# Appeding the 560th url
# Appeding the 561th url
# Appeding the 562th url
# Appeding the 563th url
# Appeding the 564th url
# Appeding the 565th url
# Appeding the 566th url
# Appeding the 567th url
# Appeding the 568th url
# Appeding the 569th url
# Appeding the 570th url
# Appeding the 571th url
# Appeding the 572th url
# Appeding the 573th url
# Appeding the 574th url
# Appeding the 575th url
# Appeding the 576th url
# Appeding the 577th url
# Appeding the 578th url
# Appeding the 579th url
# Appeding the 580th url
# Appeding the 581th url
# Appeding the 582th url
# Appeding the 583th url
# Appeding the 584th url
# Appeding the 585th url
# Appeding the 586th url
# Appeding the 587th url
# Appeding the 588th url
# Appeding the 589th url
# Appeding the 590th url
# Appeding the 591th url
# Appeding the 592th url

# %%
df=read_journal(url_list)
# Out:
# Processing the 1th paper with 0 authors
# Processing the 2th paper with 1 authors
# Processing the 3th paper with 3 authors
# Processing the 4th paper with 4 authors
# Processing the 5th paper with 2 authors
# Processing the 6th paper with 2 authors
# Processing the 7th paper with 6 authors
# Processing the 8th paper with 5 authors
# Processing the 9th paper with 2 authors
# Processing the 10th paper with 1 authors
# Processing the 11th paper with 1 authors
# Processing the 12th paper with 4 authors
# Processing the 13th paper with 5 authors
# Processing the 14th paper with 2 authors
# Processing the 15th paper with 5 authors
# Processing the 16th paper with 3 authors
# Processing the 17th paper with 0 authors
# Processing the 18th paper with 3 authors
# Processing the 19th paper with 3 authors
# Processing the 20th paper with 5 authors
# Processing the 21th paper with 3 authors
# Processing the 22th paper with 2 authors
# Processing the 23th paper with 2 authors
# Processing the 24th paper with 10 authors
# Processing the 25th paper with 4 authors
# Processing the 26th paper with 0 authors
# Processing the 27th paper with 1 authors
# Processing the 28th paper with 14 authors
# Processing the 29th paper with 5 authors
# Processing the 30th paper with 6 authors
# Processing the 31th paper with 8 authors
# Processing the 32th paper with 3 authors
# Processing the 33th paper with 6 authors
# Processing the 34th paper with 5 authors
# Processing the 35th paper with 0 authors
# Processing the 36th paper with 7 authors
# Processing the 37th paper with 1 authors
# Processing the 38th paper with 2 authors
# Processing the 39th paper with 2 authors
# Processing the 40th paper with 3 authors
# Processing the 41th paper with 1 authors
# Processing the 42th paper with 2 authors
# Processing the 43th paper with 0 authors
# Processing the 44th paper with 16 authors
# Processing the 45th paper with 5 authors
# Processing the 46th paper with 1 authors
# Processing the 47th paper with 4 authors
# Processing the 48th paper with 4 authors
# Processing the 49th paper with 1 authors
# Processing the 50th paper with 1 authors
# Processing the 51th paper with 0 authors
# Processing the 52th paper with 10 authors
# Processing the 53th paper with 2 authors
# Processing the 54th paper with 2 authors
# Processing the 55th paper with 1 authors
# Processing the 56th paper with 4 authors
# Processing the 57th paper with 1 authors
# Processing the 58th paper with 5 authors
# Processing the 59th paper with 1 authors
# Processing the 60th paper with 12 authors
# Processing the 61th paper with 4 authors
# Processing the 62th paper with 4 authors
# Processing the 63th paper with 3 authors
# Processing the 64th paper with 2 authors
# Processing the 65th paper with 1 authors
# Processing the 66th paper with 0 authors
# Processing the 67th paper with 1 authors
# Processing the 68th paper with 1 authors
# Processing the 69th paper with 5 authors
# Processing the 70th paper with 4 authors
# Processing the 71th paper with 2 authors
# Processing the 72th paper with 2 authors
# Processing the 73th paper with 6 authors
# Processing the 74th paper with 1 authors
# Processing the 75th paper with 14 authors
# Processing the 76th paper with 8 authors
# Processing the 77th paper with 1 authors
# Processing the 78th paper with 4 authors
# Processing the 79th paper with 4 authors
# Processing the 80th paper with 3 authors
# Processing the 81th paper with 2 authors
# Processing the 82th paper with 3 authors
# Processing the 83th paper with 12 authors
# Processing the 84th paper with 1 authors
# Processing the 85th paper with 2 authors
# Processing the 86th paper with 2 authors
# Processing the 87th paper with 2 authors
# Processing the 88th paper with 6 authors
# Processing the 89th paper with 5 authors
# Processing the 90th paper with 2 authors
# Processing the 91th paper with 4 authors
# Processing the 92th paper with 2 authors
# Processing the 93th paper with 2 authors
# Processing the 94th paper with 4 authors
# Processing the 95th paper with 2 authors
# Processing the 96th paper with 1 authors
# Processing the 97th paper with 1 authors
# Processing the 98th paper with 3 authors
# Processing the 99th paper with 2 authors
# Processing the 100th paper with 3 authors
# Processing the 101th paper with 3 authors
# Processing the 102th paper with 1 authors
# Processing the 103th paper with 1 authors
# Processing the 104th paper with 4 authors
# Processing the 105th paper with 8 authors
# Processing the 106th paper with 2 authors
# Processing the 107th paper with 2 authors
# Processing the 108th paper with 3 authors
# Processing the 109th paper with 1 authors
# Processing the 110th paper with 5 authors
# Processing the 111th paper with 5 authors
# Processing the 112th paper with 2 authors
# Processing the 113th paper with 1 authors
# Processing the 114th paper with 8 authors
# Processing the 115th paper with 1 authors
# Processing the 116th paper with 6 authors
# Processing the 117th paper with 1 authors
# Processing the 118th paper with 4 authors
# Processing the 119th paper with 2 authors
# Processing the 120th paper with 3 authors
# Processing the 121th paper with 4 authors
# Processing the 122th paper with 2 authors
# Processing the 123th paper with 1 authors
# Processing the 124th paper with 1 authors
# Processing the 125th paper with 1 authors
# Processing the 126th paper with 3 authors
# Processing the 127th paper with 2 authors
# Processing the 128th paper with 14 authors
# Processing the 129th paper with 2 authors
# Processing the 130th paper with 1 authors
# Processing the 131th paper with 5 authors
# Processing the 132th paper with 2 authors
# Processing the 133th paper with 2 authors
# Processing the 134th paper with 3 authors
# Processing the 135th paper with 2 authors
# Processing the 136th paper with 2 authors
# Processing the 137th paper with 1 authors
# Processing the 138th paper with 2 authors
# Processing the 139th paper with 1 authors
# Processing the 140th paper with 3 authors
# Processing the 141th paper with 2 authors
# Processing the 142th paper with 1 authors
# Processing the 143th paper with 3 authors
# Processing the 144th paper with 1 authors
# Processing the 145th paper with 6 authors
# Processing the 146th paper with 2 authors
# Processing the 147th paper with 5 authors
# Processing the 148th paper with 3 authors
# Processing the 149th paper with 1 authors
# Processing the 150th paper with 2 authors
# Processing the 151th paper with 1 authors
# Processing the 152th paper with 5 authors
# Processing the 153th paper with 2 authors
# Processing the 154th paper with 2 authors
# Processing the 155th paper with 1 authors
# Processing the 156th paper with 2 authors
# Processing the 157th paper with 3 authors
# Processing the 158th paper with 5 authors
# Processing the 159th paper with 3 authors
# Processing the 160th paper with 10 authors
# Processing the 161th paper with 1 authors
# Processing the 162th paper with 6 authors
# Processing the 163th paper with 5 authors
# Processing the 164th paper with 1 authors
# Processing the 165th paper with 4 authors
# Processing the 166th paper with 1 authors
# Processing the 167th paper with 7 authors
# Processing the 168th paper with 3 authors
# Processing the 169th paper with 8 authors
# Processing the 170th paper with 1 authors
# Processing the 171th paper with 5 authors
# Processing the 172th paper with 1 authors
# Processing the 173th paper with 1 authors
# Processing the 174th paper with 1 authors
# Processing the 175th paper with 6 authors
# Processing the 176th paper with 9 authors
# Processing the 177th paper with 0 authors
# Processing the 178th paper with 1 authors
# Processing the 179th paper with 1 authors
# Processing the 180th paper with 8 authors
# Processing the 181th paper with 1 authors
# Processing the 182th paper with 1 authors
# Processing the 183th paper with 2 authors
# Processing the 184th paper with 2 authors
# Processing the 185th paper with 4 authors
# Processing the 186th paper with 1 authors
# Processing the 187th paper with 1 authors
# Processing the 188th paper with 1 authors
# Processing the 189th paper with 1 authors
# Processing the 190th paper with 1 authors
# Processing the 191th paper with 2 authors
# Processing the 192th paper with 11 authors
# Processing the 193th paper with 3 authors
# Processing the 194th paper with 3 authors
# Processing the 195th paper with 1 authors
# Processing the 196th paper with 1 authors
# Processing the 197th paper with 1 authors
# Processing the 198th paper with 6 authors
# Processing the 199th paper with 2 authors
# Processing the 200th paper with 3 authors
# Processing the 201th paper with 7 authors
# Processing the 202th paper with 3 authors
# Processing the 203th paper with 3 authors
# Processing the 204th paper with 1 authors
# Processing the 205th paper with 3 authors
# Processing the 206th paper with 5 authors
# Processing the 207th paper with 1 authors
# Processing the 208th paper with 2 authors
# Processing the 209th paper with 1 authors
# Processing the 210th paper with 3 authors
# Processing the 211th paper with 3 authors
# Processing the 212th paper with 1 authors
# Processing the 213th paper with 1 authors
# Processing the 214th paper with 0 authors
# Processing the 215th paper with 1 authors
# Processing the 216th paper with 3 authors
# Processing the 217th paper with 1 authors
# Processing the 218th paper with 5 authors
# Processing the 219th paper with 1 authors
# Processing the 220th paper with 1 authors
# Processing the 221th paper with 3 authors
# Processing the 222th paper with 1 authors
# Processing the 223th paper with 1 authors
# Processing the 224th paper with 2 authors
# Processing the 225th paper with 2 authors
# Processing the 226th paper with 2 authors
# Processing the 227th paper with 1 authors
# Processing the 228th paper with 2 authors
# Processing the 229th paper with 2 authors
# Processing the 230th paper with 4 authors
# Processing the 231th paper with 1 authors
# Processing the 232th paper with 1 authors
# Processing the 233th paper with 1 authors
# Processing the 234th paper with 1 authors
# Processing the 235th paper with 1 authors
# Processing the 236th paper with 1 authors
# Processing the 237th paper with 1 authors
# Processing the 238th paper with 1 authors
# Processing the 239th paper with 1 authors
# Processing the 240th paper with 1 authors
# Processing the 241th paper with 1 authors
# Processing the 242th paper with 0 authors
# Processing the 243th paper with 0 authors
# Processing the 244th paper with 15 authors
# Processing the 245th paper with 2 authors
# Processing the 246th paper with 1 authors
# Processing the 247th paper with 1 authors
# Processing the 248th paper with 3 authors
# Processing the 249th paper with 3 authors
# Processing the 250th paper with 3 authors
# Processing the 251th paper with 2 authors
# Processing the 252th paper with 1 authors
# Processing the 253th paper with 6 authors
# Processing the 254th paper with 4 authors
# Processing the 255th paper with 1 authors
# Processing the 256th paper with 2 authors
# Processing the 257th paper with 4 authors
# Processing the 258th paper with 1 authors
# Processing the 259th paper with 4 authors
# Processing the 260th paper with 4 authors
# Processing the 261th paper with 3 authors
# Processing the 262th paper with 1 authors
# Processing the 263th paper with 1 authors
# Processing the 264th paper with 1 authors
# Processing the 265th paper with 4 authors
# Processing the 266th paper with 1 authors
# Processing the 267th paper with 1 authors
# Processing the 268th paper with 1 authors
# Processing the 269th paper with 6 authors
# Processing the 270th paper with 3 authors
# Processing the 271th paper with 4 authors
# Processing the 272th paper with 1 authors
# Processing the 273th paper with 2 authors
# Processing the 274th paper with 2 authors
# Processing the 275th paper with 3 authors
# Processing the 276th paper with 4 authors
# Processing the 277th paper with 3 authors
# Processing the 278th paper with 8 authors
# Processing the 279th paper with 1 authors
# Processing the 280th paper with 2 authors
# Processing the 281th paper with 3 authors
# Processing the 282th paper with 2 authors
# Processing the 283th paper with 0 authors
# Processing the 284th paper with 3 authors
# Processing the 285th paper with 1 authors
# Processing the 286th paper with 2 authors
# Processing the 287th paper with 1 authors
# Processing the 288th paper with 1 authors
# Processing the 289th paper with 1 authors
# Processing the 290th paper with 2 authors
# Processing the 291th paper with 2 authors
# Processing the 292th paper with 2 authors
# Processing the 293th paper with 1 authors
# Processing the 294th paper with 1 authors
# Processing the 295th paper with 1 authors
# Processing the 296th paper with 5 authors
# Processing the 297th paper with 1 authors
# Processing the 298th paper with 3 authors
# Processing the 299th paper with 2 authors
# Processing the 300th paper with 2 authors
# Processing the 301th paper with 2 authors
# Processing the 302th paper with 1 authors
# Processing the 303th paper with 1 authors
# Processing the 304th paper with 2 authors
# Processing the 305th paper with 1 authors
# Processing the 306th paper with 1 authors
# Processing the 307th paper with 1 authors
# Processing the 308th paper with 2 authors
# Processing the 309th paper with 4 authors
# Processing the 310th paper with 2 authors
# Processing the 311th paper with 4 authors
# Processing the 312th paper with 1 authors
# Processing the 313th paper with 3 authors
# Processing the 314th paper with 4 authors
# Processing the 315th paper with 3 authors
# Processing the 316th paper with 3 authors
# Processing the 317th paper with 2 authors
# Processing the 318th paper with 1 authors
# Processing the 319th paper with 2 authors
# Processing the 320th paper with 2 authors
# Processing the 321th paper with 1 authors
# Processing the 322th paper with 1 authors
# Processing the 323th paper with 0 authors
# Processing the 324th paper with 0 authors
# Processing the 325th paper with 1 authors
# Processing the 326th paper with 3 authors
# Processing the 327th paper with 1 authors
# Processing the 328th paper with 1 authors
# Processing the 329th paper with 2 authors
# Processing the 330th paper with 1 authors
# Processing the 331th paper with 1 authors
# Processing the 332th paper with 1 authors
# Processing the 333th paper with 4 authors
# Processing the 334th paper with 2 authors
# Processing the 335th paper with 1 authors
# Processing the 336th paper with 3 authors
# Processing the 337th paper with 1 authors
# Processing the 338th paper with 1 authors
# Processing the 339th paper with 1 authors
# Processing the 340th paper with 2 authors
# Processing the 341th paper with 1 authors
# Processing the 342th paper with 1 authors
# Processing the 343th paper with 0 authors
# Processing the 344th paper with 2 authors
# Processing the 345th paper with 3 authors
# Processing the 346th paper with 1 authors
# Processing the 347th paper with 1 authors
# Processing the 348th paper with 3 authors
# Processing the 349th paper with 1 authors
# Processing the 350th paper with 1 authors
# Processing the 351th paper with 1 authors
# Processing the 352th paper with 6 authors
# Processing the 353th paper with 1 authors
# Processing the 354th paper with 1 authors
# Processing the 355th paper with 1 authors
# Processing the 356th paper with 1 authors
# Processing the 357th paper with 7 authors
# Processing the 358th paper with 2 authors
# Processing the 359th paper with 1 authors
# Processing the 360th paper with 3 authors
# Processing the 361th paper with 2 authors
# Processing the 362th paper with 3 authors
# Processing the 363th paper with 1 authors
# Processing the 364th paper with 0 authors
# Processing the 365th paper with 1 authors
# Processing the 366th paper with 1 authors
# Processing the 367th paper with 1 authors
# Processing the 368th paper with 1 authors
# Processing the 369th paper with 0 authors
# Processing the 370th paper with 0 authors
# Processing the 371th paper with 1 authors
# Processing the 372th paper with 1 authors
# Processing the 373th paper with 1 authors
# Processing the 374th paper with 1 authors
# Processing the 375th paper with 2 authors
# Processing the 376th paper with 2 authors
# Processing the 377th paper with 10 authors
# Processing the 378th paper with 1 authors
# Processing the 379th paper with 1 authors
# Processing the 380th paper with 1 authors
# Processing the 381th paper with 2 authors
# Processing the 382th paper with 2 authors
# Processing the 383th paper with 5 authors
# Processing the 384th paper with 1 authors
# Processing the 385th paper with 3 authors
# Processing the 386th paper with 1 authors
# Processing the 387th paper with 1 authors
# Processing the 388th paper with 2 authors
# Processing the 389th paper with 3 authors
# Processing the 390th paper with 1 authors
# Processing the 391th paper with 1 authors
# Processing the 392th paper with 3 authors
# Processing the 393th paper with 1 authors
# Processing the 394th paper with 1 authors
# Processing the 395th paper with 4 authors
# Processing the 396th paper with 2 authors
# Processing the 397th paper with 1 authors
# Processing the 398th paper with 0 authors
# Processing the 399th paper with 3 authors
# Processing the 400th paper with 1 authors
# Processing the 401th paper with 1 authors
# Processing the 402th paper with 3 authors
# Processing the 403th paper with 1 authors
# Processing the 404th paper with 2 authors
# Processing the 405th paper with 2 authors
# Processing the 406th paper with 2 authors
# Processing the 407th paper with 2 authors
# Processing the 408th paper with 6 authors
# Processing the 409th paper with 1 authors
# Processing the 410th paper with 2 authors
# Processing the 411th paper with 1 authors
# Processing the 412th paper with 1 authors
# Processing the 413th paper with 1 authors
# Processing the 414th paper with 3 authors
# Processing the 415th paper with 1 authors
# Processing the 416th paper with 1 authors
# Processing the 417th paper with 0 authors
# Processing the 418th paper with 1 authors
# Processing the 419th paper with 1 authors
# Processing the 420th paper with 3 authors
# Processing the 421th paper with 5 authors
# Processing the 422th paper with 0 authors
# Processing the 423th paper with 1 authors
# Processing the 424th paper with 2 authors
# Processing the 425th paper with 2 authors
# Processing the 426th paper with 2 authors
# Processing the 427th paper with 1 authors
# Processing the 428th paper with 4 authors
# Processing the 429th paper with 2 authors
# Processing the 430th paper with 2 authors
# Processing the 431th paper with 1 authors
# Processing the 432th paper with 0 authors
# Processing the 433th paper with 0 authors
# Processing the 434th paper with 1 authors
# Processing the 435th paper with 3 authors
# Processing the 436th paper with 4 authors
# Processing the 437th paper with 1 authors
# Processing the 438th paper with 3 authors
# Processing the 439th paper with 3 authors
# Processing the 440th paper with 4 authors
# Processing the 441th paper with 2 authors
# Processing the 442th paper with 2 authors
# Processing the 443th paper with 1 authors
# Processing the 444th paper with 1 authors
# Processing the 445th paper with 1 authors
# Processing the 446th paper with 2 authors
# Processing the 447th paper with 2 authors
# Processing the 448th paper with 2 authors
# Processing the 449th paper with 1 authors
# Processing the 450th paper with 2 authors
# Processing the 451th paper with 1 authors
# Processing the 452th paper with 5 authors
# Processing the 453th paper with 15 authors
# Processing the 454th paper with 3 authors
# Processing the 455th paper with 2 authors
# Processing the 456th paper with 1 authors
# Processing the 457th paper with 2 authors
# Processing the 458th paper with 1 authors
# Processing the 459th paper with 8 authors
# Processing the 460th paper with 2 authors
# Processing the 461th paper with 1 authors
# Processing the 462th paper with 1 authors
# Processing the 463th paper with 1 authors
# Processing the 464th paper with 4 authors
# Processing the 465th paper with 1 authors
# Processing the 466th paper with 2 authors
# Processing the 467th paper with 0 authors
# Processing the 468th paper with 2 authors
# Processing the 469th paper with 1 authors
# Processing the 470th paper with 1 authors
# Processing the 471th paper with 1 authors
# Processing the 472th paper with 1 authors
# Processing the 473th paper with 1 authors
# Processing the 474th paper with 0 authors
# Processing the 475th paper with 1 authors
# Processing the 476th paper with 3 authors
# Processing the 477th paper with 1 authors
# Processing the 478th paper with 1 authors
# Processing the 479th paper with 4 authors
# Processing the 480th paper with 0 authors
# Processing the 481th paper with 1 authors
# Processing the 482th paper with 1 authors
# Processing the 483th paper with 3 authors
# Processing the 484th paper with 2 authors
# Processing the 485th paper with 1 authors
# Processing the 486th paper with 0 authors
# Processing the 487th paper with 1 authors
# Processing the 488th paper with 1 authors
# Processing the 489th paper with 2 authors
# Processing the 490th paper with 2 authors
# Processing the 491th paper with 0 authors
# Processing the 492th paper with 0 authors
# Processing the 493th paper with 2 authors
# Processing the 494th paper with 2 authors
# Processing the 495th paper with 1 authors
# Processing the 496th paper with 1 authors
# Processing the 497th paper with 1 authors
# Processing the 498th paper with 3 authors
# Processing the 499th paper with 1 authors
# Processing the 500th paper with 1 authors
# Processing the 501th paper with 1 authors
# Processing the 502th paper with 0 authors
# Processing the 503th paper with 2 authors
# Processing the 504th paper with 1 authors
# Processing the 505th paper with 2 authors
# Processing the 506th paper with 1 authors
# Processing the 507th paper with 2 authors
# Processing the 508th paper with 0 authors
# Processing the 509th paper with 1 authors
# Processing the 510th paper with 1 authors
# Processing the 511th paper with 1 authors
# Processing the 512th paper with 4 authors
# Processing the 513th paper with 2 authors
# Processing the 514th paper with 0 authors
# Processing the 515th paper with 4 authors
# Processing the 516th paper with 1 authors
# Processing the 517th paper with 2 authors
# Processing the 518th paper with 0 authors
# Processing the 519th paper with 2 authors
# Processing the 520th paper with 1 authors
# Processing the 521th paper with 2 authors
# Processing the 522th paper with 0 authors
# Processing the 523th paper with 1 authors
# Processing the 524th paper with 1 authors
# Processing the 525th paper with 1 authors
# Processing the 526th paper with 2 authors
# Processing the 527th paper with 3 authors
# Processing the 528th paper with 2 authors
# Processing the 529th paper with 1 authors
# Processing the 530th paper with 7 authors
# Processing the 531th paper with 2 authors
# Processing the 532th paper with 6 authors
# Processing the 533th paper with 0 authors
# Processing the 534th paper with 0 authors
# Processing the 535th paper with 3 authors
# Processing the 536th paper with 1 authors
# Processing the 537th paper with 1 authors
# Processing the 538th paper with 0 authors
# Processing the 539th paper with 2 authors
# Processing the 540th paper with 2 authors
# Processing the 541th paper with 3 authors
# Processing the 542th paper with 4 authors
# Processing the 543th paper with 4 authors
# Processing the 544th paper with 2 authors
# Processing the 545th paper with 1 authors
# Processing the 546th paper with 1 authors
# Processing the 547th paper with 3 authors
# Processing the 548th paper with 2 authors
# Processing the 549th paper with 1 authors
# Processing the 550th paper with 0 authors
# Processing the 551th paper with 0 authors
# Processing the 552th paper with 3 authors
# Processing the 553th paper with 0 authors
# Processing the 554th paper with 2 authors
# Processing the 555th paper with 1 authors
# Processing the 556th paper with 0 authors
# Processing the 557th paper with 2 authors
# Processing the 558th paper with 1 authors
# Processing the 559th paper with 1 authors
# Processing the 560th paper with 1 authors
# Processing the 561th paper with 1 authors
# Processing the 562th paper with 1 authors
# Processing the 563th paper with 1 authors
# Processing the 564th paper with 1 authors
# Processing the 565th paper with 2 authors
# Processing the 566th paper with 3 authors
# Processing the 567th paper with 1 authors
# Processing the 568th paper with 1 authors
# Processing the 569th paper with 1 authors
# Processing the 570th paper with 1 authors
# Processing the 571th paper with 1 authors
# Processing the 572th paper with 1 authors
# Processing the 573th paper with 1 authors
# Processing the 574th paper with 1 authors
# Processing the 575th paper with 1 authors
# Processing the 576th paper with 1 authors
# Processing the 577th paper with 0 authors
# Processing the 578th paper with 1 authors
# Processing the 579th paper with 1 authors
# Processing the 580th paper with 1 authors
# Processing the 581th paper with 0 authors
# Processing the 582th paper with 2 authors
# Processing the 583th paper with 3 authors
# Processing the 584th paper with 1 authors
# Processing the 585th paper with 0 authors
# Processing the 586th paper with 1 authors
# Processing the 587th paper with 1 authors
# Processing the 588th paper with 1 authors
# Processing the 589th paper with 1 authors
# Processing the 590th paper with 0 authors
# Processing the 591th paper with 1 authors
# Processing the 592th paper with 1 authors

# %%
df.to_csv('American_Antiquity.csv')

# %%
df
# Out:
#                                        DOI             Journal      Type  \
# 0     https://doi.org/10.1017/aaq.2021.120  American Antiquity     Forum
# 1     https://doi.org/10.1017/aaq.2021.115  American Antiquity   Article
# 2     https://doi.org/10.1017/aaq.2021.115  American Antiquity   Article
# 3     https://doi.org/10.1017/aaq.2021.115  American Antiquity   Article
# 4     https://doi.org/10.1017/aaq.2021.119  American Antiquity   Article
# ...                                    ...                 ...       ...
# 1350       https://doi.org/10.2307/2694057  American Antiquity  Articles
# 1351       https://doi.org/10.2307/2694058  American Antiquity  Articles
# 1352       https://doi.org/10.2307/2694059  American Antiquity  Articles
# 1353       https://doi.org/10.2307/2694805  American Antiquity     Forum
# 1354       https://doi.org/10.2307/2694806  American Antiquity  Articles
#
#                                                   Title      Publish_Time  \
# 0     On Rehumanizing Pleistocene People of the West...  01 December 2021
# 1     Direct Evidence for Geophyte Exploitation in t...  02 November 2021
# 2     Direct Evidence for Geophyte Exploitation in t...  02 November 2021
# 3     Direct Evidence for Geophyte Exploitation in t...  02 November 2021
# 4     Regional Conflict, Ceramic Senescence, and Paw...  02 December 2021
# ...                                                 ...               ...
# 1350  Questions of Evidence, Legitimacy, and the (Di...   20 January 2017
# 1351  Archaeology and Native North American Oral Tra...   20 January 2017
# 1352  Ancient History in the New World: Integrating ...   20 January 2017
# 1353  Gazing upon the Invisible: Women and Children ...   20 January 2017
# 1354  Social Formations, Modo de Vida, and Conflict ...   20 January 2017
#
#          Issue_Time Co_Author                 Author           Rank  \
# 0        April 2022     False     Bonnie L. Pitblado          First
# 1        April 2022      True            Kaley Joyce          First
# 2        April 2022      True  Lisbeth A. Louderback          Other
# 3        April 2022      True         Erick Robinson  Communication
# 4        April 2022      True       Margaret E. Beck          First
# ...             ...       ...                    ...            ...
# 1350     April 2000     False           Alison Wylie          First
# 1351     April 2000     False        Ronald J. Mason          First
# 1352     April 2000     False     Roger C. Echo-Hawk          First
# 1353   January 2000     False       Connie H. Nobles          First
# 1354   January 2000     False       Bradley E. Ensor          First
#
#                        Nationality Abs_country               Abs_GPE  \
# 0     USA (bonnie.pitblado@ou.edu)          []  [Folsom, New Mexico]
# 1                              USA        [10]             [Wyoming]
# 2                              USA        [10]             [Wyoming]
# 3                              USA        [10]             [Wyoming]
# 4                              USA          []     [Kitkahahki Town]
# ...                            ...         ...                   ...
# 1350                      MO 63130          []                    []
# 1351                 WI 54912-0599          []                    []
# 1352                 Co 80204-2788          []        [North Dakota]
# 1353                      LA 70402          []         [Gordon 1980]
# 1354                      AZ 85281          []                [U.S.]
#
#                                      Abs_LOC
# 0                   [the Western Hemisphere]
# 1     [the Wyoming Basin, the Wyoming Basin]
# 2     [the Wyoming Basin, the Wyoming Basin]
# 3     [the Wyoming Basin, the Wyoming Basin]
# 4                 [the Central Great Plains]
# ...                                      ...
# 1350                                      []
# 1351                                      []
# 1352                         [North America]
# 1353                                      []
# 1354                                      []
#
# [1355 rows x 13 columns]
